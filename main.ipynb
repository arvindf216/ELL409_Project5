# %%
# imports
import numpy as np
import tensorflow as tf
# !pip install gensim #install gensim if not installed
from gensim.models import Word2Vec
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Embedding, Bidirectional, Dense, Input, Dropout,LSTM
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import Callback
import random
import numpy
# Out:
# Requirement already satisfied: gensim in /opt/conda/lib/python3.10/site-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /opt/conda/lib/python3.10/site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/conda/lib/python3.10/site-packages (from gensim) (7.0.4)
# Requirement already satisfied: wrapt in /opt/conda/lib/python3.10/site-packages (from smart-open>=1.8.1->gensim) (1.16.0)

# %%
# Load and prepare the dataset
def load_dataset(file_path):
    with open(file_path, 'r') as f:
        return f.read().splitlines()

# Tokenize text
def tokenize_text(texts):
    texts = [line.strip() for line in texts if line.strip()]
    tokenizer = Tokenizer(filters='') 
    tokenizer.fit_on_texts(texts)
    sequences = tokenizer.texts_to_sequences(texts)
    return sequences, tokenizer

def train_word2vec_model(texts, vector_size=100):
    sentences = [text.split() for text in texts]
    model = Word2Vec(sentences, vector_size=vector_size, window=5, min_count=1, workers=4)
    return model

# %%
from tensorflow.keras.layers import Dense, Embedding, LSTM, Input, Dropout, Bidirectional,Concatenate

def create_seq2seq_model(input_vocab_size, output_vocab_size, embedding_dim, encoder_hidden_size, decoder_hidden_size, embedding_layer, dropout_rate=0.3):
    # Encoder
    encoder_input = Input(shape=(None,))
    encoder_embedding = embedding_layer(encoder_input)
    encoder_bilstm = Bidirectional(LSTM(encoder_hidden_size, return_state=True))  # BiLSTM
    encoder_output, forward_h, forward_c, backward_h, backward_c = encoder_bilstm(encoder_embedding)
    
    # Concatenate the forward and backward hidden states and cells
    encoder_state_h = Concatenate()([forward_h, backward_h])  # Shape: (None, 2*encoder_hidden_size)
    encoder_state_c = Concatenate()([forward_c, backward_c])  # Shape: (None, 2*encoder_hidden_size)
    
    # Add a Dense layer to match the decoder's hidden size (500)
    decoder_state_h = Dense(decoder_hidden_size)(encoder_state_h)  # Project to (None, decoder_hidden_size)
    decoder_state_c = Dense(decoder_hidden_size)(encoder_state_c)  # Project to (None, decoder_hidden_size)
    encoder_states = [decoder_state_h, decoder_state_c]

    # Decoder
    decoder_input = Input(shape=(None,))
    decoder_embedding = embedding_layer(decoder_input)
    decoder_lstm = LSTM(decoder_hidden_size, return_state=True, return_sequences=True)
    decoder_output, _, _ = decoder_lstm(decoder_embedding, initial_state=encoder_states)

    # Add dropout after decoder LSTM
    decoder_output = Dropout(dropout_rate)(decoder_output)

    decoder_dense = Dense(output_vocab_size, activation='softmax')
    decoder_output = decoder_dense(decoder_output)

    model = Model([encoder_input, decoder_input], decoder_output)
    return model

class PerplexityCallback(Callback):
    def on_epoch_end(self, epoch, logs=None):
        loss = logs.get('loss')
        perplexity = np.exp(loss) if loss is not None else 0
        print(f' Epoch {epoch+1} - Perplexity: {perplexity}')

# %%
# Load dataset
texts = load_dataset('/kaggle/input/frost-poems/frost_poems.txt')
# replace by suitable path

# Tokenize text and get vocab size, prepare for Word2Vec
sequences, tokenizer = tokenize_text(texts)
vocab_size = len(tokenizer.word_index) + 1

# pretrained word2vec
from gensim.models import KeyedVectors
word2vec_model = KeyedVectors.load_word2vec_format('/kaggle/input/nlpword2vecembeddingspretrained/GoogleNews-vectors-negative300.bin', binary=True)
# replace by suitable path

# Preparing the embedding matrix
embedding_dim = word2vec_model.vector_size
embedding_matrix = np.zeros((vocab_size, embedding_dim))
for word, i in tokenizer.word_index.items():
    if word in word2vec_model:
        embedding_matrix[i] = word2vec_model[word]

# Prepare input-output pairs
input_sequences = sequences[:-1]  # All but last line
output_sequences = sequences[1:]  # All but first line

# Pad sequences
max_input_len = max(len(seq) for seq in input_sequences)
max_output_len = max(len(seq) for seq in output_sequences)
input_sequences = pad_sequences(input_sequences, maxlen=max_input_len, padding='post')
output_sequences = pad_sequences(output_sequences, maxlen=max_output_len, padding='post')
    
data_size = len(input_sequences)
split_index = int(data_size * 0.8)
train_input = input_sequences[:split_index]
train_output = output_sequences[:split_index]
test_input = input_sequences[split_index:]
test_output = output_sequences[split_index:]

# Convert lists to numpy arrays
train_input = np.array(train_input)
train_output = np.array(train_output)
test_input = np.array(test_input)
test_output = np.array(test_output)

# %%
# Create the Seq2Seq model
embedding_layer = Embedding(vocab_size, embedding_dim, weights=[embedding_matrix], trainable=False)
encoder_hidden_size = 100
decoder_hidden_size = 200
dropout = 0.3
learning_rate=0.0005
model = create_seq2seq_model(vocab_size, vocab_size, embedding_dim, encoder_hidden_size, decoder_hidden_size, embedding_layer,dropout)

# Compile the model
model.compile(optimizer=Adam(learning_rate), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
print(model.summary())

# Train the model with Perplexity callback and teacher forcing
model.fit(
    [train_input, train_output[:, :-1]],  # input and shifted output
    np.expand_dims(train_output[:, 1:], -1),  # target for next word
    batch_size=16,
    epochs=100,
    callbacks=[PerplexityCallback()]
)

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate([test_input, test_output[:, :-1]], np.expand_dims(test_output[:, 1:], -1))
test_perplexity = np.exp(test_loss)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
print(f"Test Perplexity: {test_perplexity}")

print("\nSample Predictions using the test set:")

for i in range(5): 
    idx = random.randint(0, len(test_input) - 1)
    input_seq = test_input[idx]
    actual_output_seq = test_output[idx]
    input_words = [tokenizer.index_word.get(idx, '<UNK>') for idx in input_seq if idx != 0]
    actual_words = [tokenizer.index_word.get(idx, '<UNK>') for idx in actual_output_seq if idx != 0]
    input_seq_expanded = np.expand_dims(input_seq, 0)  
    predicted_output = model.predict([input_seq_expanded, np.expand_dims(actual_output_seq[:-1], 0)], verbose=0)
    pred_indices = [np.random.choice(len(prob), p=prob) for prob in predicted_output[0]]
    predicted_words = [tokenizer.index_word.get(idx, '<UNK>') for idx in pred_indices if idx != 0]
    print(f"Input: {' '.join(input_words)}")
    print(f"Actual Output: {' '.join(actual_words)}")
    print(f"Predicted Output: {' '.join(predicted_words)}")
    print()
# Out:
# Model: "functional_39"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_39      │ (None, None)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_38      │ (None, None)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_19        │ (None, None, 300) │  1,089,900 │ input_layer_38[0… │
# │ (Embedding)         │                   │            │ input_layer_39[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_19    │ [(None, 200),     │    320,800 │ embedding_19[0][… │
# │ (Bidirectional)     │ (None, 100),      │            │                   │
# │                     │ (None, 100),      │            │                   │
# │                     │ (None, 100),      │            │                   │
# │                     │ (None, 100)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_38      │ (None, 200)       │          0 │ bidirectional_19… │
# │ (Concatenate)       │                   │            │ bidirectional_19… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_39      │ (None, 200)       │          0 │ bidirectional_19… │
# │ (Concatenate)       │                   │            │ bidirectional_19… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_57 (Dense)    │ (None, 200)       │     40,200 │ concatenate_38[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_58 (Dense)    │ (None, 200)       │     40,200 │ concatenate_39[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_39 (LSTM)      │ [(None, None,     │    400,800 │ embedding_19[1][… │
# │                     │ 200), (None,      │            │ dense_57[0][0],   │
# │                     │ 200), (None,      │            │ dense_58[0][0]    │
# │                     │ 200)]             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_19          │ (None, None, 200) │          0 │ lstm_39[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_59 (Dense)    │ (None, None,      │    730,233 │ dropout_19[0][0]  │
# │                     │ 3633)             │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,622,133 (10.00 MB)
#  Trainable params: 1,532,233 (5.85 MB)
#  Non-trainable params: 1,089,900 (4.16 MB)
# None
# Epoch 1/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3684 - loss: 6.0807 Epoch 1 - Perplexity: 146.61437540661643
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.3686 - loss: 6.0726
# Epoch 2/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4107 - loss: 4.1415 Epoch 2 - Perplexity: 63.71857783196339
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4107 - loss: 4.1416
# Epoch 3/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4121 - loss: 4.0784 Epoch 3 - Perplexity: 59.28741064767698
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4121 - loss: 4.0784
# Epoch 4/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4104 - loss: 4.0373 Epoch 4 - Perplexity: 56.81989193887974
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4104 - loss: 4.0373
# Epoch 5/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4159 - loss: 3.9893 Epoch 5 - Perplexity: 54.88507172945584
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4158 - loss: 3.9894
# Epoch 6/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4159 - loss: 3.9437 Epoch 6 - Perplexity: 52.87658409095087
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4159 - loss: 3.9439
# Epoch 7/100
# 130/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4145 - loss: 3.9265 Epoch 7 - Perplexity: 51.368329542118516
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4146 - loss: 3.9268
# Epoch 8/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4230 - loss: 3.8656 Epoch 8 - Perplexity: 49.570452352245184
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4230 - loss: 3.8659
# Epoch 9/100
# 132/133 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4199 - loss: 3.8678 Epoch 9 - Perplexity: 48.01441159234825
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4199 - loss: 3.8679
# Epoch 10/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4217 - loss: 3.8269 Epoch 10 - Perplexity: 46.63601667865222
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4217 - loss: 3.8270
# Epoch 11/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4214 - loss: 3.8106 Epoch 11 - Perplexity: 44.94898427597931
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4214 - loss: 3.8105
# Epoch 12/100
# 132/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4268 - loss: 3.7432 Epoch 12 - Perplexity: 43.35749195830013
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4267 - loss: 3.7436
# Epoch 13/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4251 - loss: 3.7294 Epoch 13 - Perplexity: 42.11952531546153
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4251 - loss: 3.7295
# Epoch 14/100
# 132/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4281 - loss: 3.6727 Epoch 14 - Perplexity: 40.70784796029285
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4281 - loss: 3.6732
# Epoch 15/100
# 129/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4241 - loss: 3.6728 Epoch 15 - Perplexity: 39.30125853704355
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4242 - loss: 3.6728
# Epoch 16/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4266 - loss: 3.6372 Epoch 16 - Perplexity: 38.108563989760285
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4266 - loss: 3.6372
# Epoch 17/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4306 - loss: 3.5964 Epoch 17 - Perplexity: 37.05261834314906
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4305 - loss: 3.5965
# Epoch 18/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4287 - loss: 3.5583 Epoch 18 - Perplexity: 35.8285267061244
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4287 - loss: 3.5584
# Epoch 19/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4323 - loss: 3.5348 Epoch 19 - Perplexity: 34.81518340945674
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4323 - loss: 3.5349
# Epoch 20/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4317 - loss: 3.5138 Epoch 20 - Perplexity: 33.708451567997805
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4317 - loss: 3.5138
# Epoch 21/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4294 - loss: 3.4827 Epoch 21 - Perplexity: 32.56907281897569
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4295 - loss: 3.4827
# Epoch 22/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4316 - loss: 3.4488 Epoch 22 - Perplexity: 31.392259083463628
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4316 - loss: 3.4488
# Epoch 23/100
# 132/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4317 - loss: 3.4144 Epoch 23 - Perplexity: 30.4741329392151
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4318 - loss: 3.4145
# Epoch 24/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4325 - loss: 3.3703 Epoch 24 - Perplexity: 29.419524544393425
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4326 - loss: 3.3704
# Epoch 25/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4350 - loss: 3.3490 Epoch 25 - Perplexity: 28.46540008693191
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4350 - loss: 3.3490
# Epoch 26/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4375 - loss: 3.3002 Epoch 26 - Perplexity: 27.569832639072803
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4375 - loss: 3.3004
# Epoch 27/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4363 - loss: 3.2720 Epoch 27 - Perplexity: 26.74121496832489
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4363 - loss: 3.2721
# Epoch 28/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4375 - loss: 3.2483 Epoch 28 - Perplexity: 25.69808739634356
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4375 - loss: 3.2483
# Epoch 29/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4389 - loss: 3.2216 Epoch 29 - Perplexity: 24.91459716285059
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4389 - loss: 3.2216
# Epoch 30/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4468 - loss: 3.1533 Epoch 30 - Perplexity: 24.14275941719671
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4468 - loss: 3.1535
# Epoch 31/100
# 132/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4469 - loss: 3.1131 Epoch 31 - Perplexity: 23.22367236783357
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4469 - loss: 3.1136
# Epoch 32/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4429 - loss: 3.1076 Epoch 32 - Perplexity: 22.36763379404971
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4429 - loss: 3.1076
# Epoch 33/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4437 - loss: 3.0719 Epoch 33 - Perplexity: 21.68656746420407
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4437 - loss: 3.0719
# Epoch 34/100
# 132/133 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4463 - loss: 3.0254 Epoch 34 - Perplexity: 20.850870869909087
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4463 - loss: 3.0256
# Epoch 35/100
# 132/133 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4472 - loss: 2.9944 Epoch 35 - Perplexity: 20.20092195660063
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4473 - loss: 2.9946
# Epoch 36/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4519 - loss: 2.9457 Epoch 36 - Perplexity: 19.494522779547495
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4519 - loss: 2.9459
# Epoch 37/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4522 - loss: 2.9126 Epoch 37 - Perplexity: 18.79521083661596
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4522 - loss: 2.9128
# Epoch 38/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4525 - loss: 2.8768 Epoch 38 - Perplexity: 18.237667767627155
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4525 - loss: 2.8770
# Epoch 39/100
# 131/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4556 - loss: 2.8595 Epoch 39 - Perplexity: 17.554849197025447
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4556 - loss: 2.8596
# Epoch 40/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4618 - loss: 2.8075 Epoch 40 - Perplexity: 16.89875969914978
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4618 - loss: 2.8077
# Epoch 41/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4670 - loss: 2.7484 Epoch 41 - Perplexity: 16.44817892533211
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4670 - loss: 2.7488
# Epoch 42/100
# 131/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4556 - loss: 2.7682 Epoch 42 - Perplexity: 15.820763352997622
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4557 - loss: 2.7680
# Epoch 43/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4620 - loss: 2.7247 Epoch 43 - Perplexity: 15.24522425902126
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4620 - loss: 2.7247
# Epoch 44/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4718 - loss: 2.6504 Epoch 44 - Perplexity: 14.676461686433928
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4718 - loss: 2.6507
# Epoch 45/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4713 - loss: 2.6417 Epoch 45 - Perplexity: 14.201159985067553
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4713 - loss: 2.6418
# Epoch 46/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4777 - loss: 2.6128 Epoch 46 - Perplexity: 13.712486968023741
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4777 - loss: 2.6129
# Epoch 47/100
# 130/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4785 - loss: 2.5899 Epoch 47 - Perplexity: 13.224419801478838
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4786 - loss: 2.5897
# Epoch 48/100
# 132/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4825 - loss: 2.5436 Epoch 48 - Perplexity: 12.858473370067488
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4825 - loss: 2.5438
# Epoch 49/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4948 - loss: 2.4762 Epoch 49 - Perplexity: 12.38349840866664
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4948 - loss: 2.4765
# Epoch 50/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4985 - loss: 2.4706 Epoch 50 - Perplexity: 12.030058581374353
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4985 - loss: 2.4707
# Epoch 51/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4984 - loss: 2.4477 Epoch 51 - Perplexity: 11.528627370355453
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4984 - loss: 2.4477
# Epoch 52/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5098 - loss: 2.4097 Epoch 52 - Perplexity: 11.216196786249167
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5098 - loss: 2.4098
# Epoch 53/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5130 - loss: 2.3678 Epoch 53 - Perplexity: 10.850659324084159
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5130 - loss: 2.3679
# Epoch 54/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5184 - loss: 2.3432 Epoch 54 - Perplexity: 10.474477297466288
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5183 - loss: 2.3433
# Epoch 55/100
# 131/133 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5278 - loss: 2.3058 Epoch 55 - Perplexity: 10.16281388611211
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5277 - loss: 2.3061
# Epoch 56/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5312 - loss: 2.2786 Epoch 56 - Perplexity: 9.904347050638247
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5312 - loss: 2.2787
# Epoch 57/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5414 - loss: 2.2348 Epoch 57 - Perplexity: 9.549017363363479
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5413 - loss: 2.2350
# Epoch 58/100
# 132/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5443 - loss: 2.1960 Epoch 58 - Perplexity: 9.318323289729673
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5442 - loss: 2.1965
# Epoch 59/100
# 131/133 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5483 - loss: 2.1875 Epoch 59 - Perplexity: 9.071115923629563
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5482 - loss: 2.1878
# Epoch 60/100
# 129/133 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5595 - loss: 2.1318 Epoch 60 - Perplexity: 8.693683283427996
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5593 - loss: 2.1329
# Epoch 61/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5576 - loss: 2.1213 Epoch 61 - Perplexity: 8.473166093086896
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5576 - loss: 2.1214
# Epoch 62/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5607 - loss: 2.1056 Epoch 62 - Perplexity: 8.2066296521324
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5607 - loss: 2.1056
# Epoch 63/100
# 131/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5717 - loss: 2.0617 Epoch 63 - Perplexity: 8.057139400225326
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5715 - loss: 2.0623
# Epoch 64/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5771 - loss: 2.0387 Epoch 64 - Perplexity: 7.8438128273225765
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5770 - loss: 2.0388
# Epoch 65/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5829 - loss: 2.0173 Epoch 65 - Perplexity: 7.5772822307567065
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5829 - loss: 2.0174
# Epoch 66/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5848 - loss: 1.9828 Epoch 66 - Perplexity: 7.38711849593845
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5847 - loss: 1.9829
# Epoch 67/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5885 - loss: 1.9545 Epoch 67 - Perplexity: 7.2298803675268735
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5885 - loss: 1.9547
# Epoch 68/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5999 - loss: 1.9103 Epoch 68 - Perplexity: 7.049093162985918
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5999 - loss: 1.9106
# Epoch 69/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5959 - loss: 1.9183 Epoch 69 - Perplexity: 6.843436476175261
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5959 - loss: 1.9183
# Epoch 70/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6079 - loss: 1.8721 Epoch 70 - Perplexity: 6.647709288451892
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6079 - loss: 1.8723
# Epoch 71/100
# 131/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6054 - loss: 1.8633 Epoch 71 - Perplexity: 6.508654193164605
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6053 - loss: 1.8636
# Epoch 72/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6159 - loss: 1.8194 Epoch 72 - Perplexity: 6.350589841825951
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6158 - loss: 1.8196
# Epoch 73/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6160 - loss: 1.8176 Epoch 73 - Perplexity: 6.21607638075957
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6160 - loss: 1.8176
# Epoch 74/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6156 - loss: 1.8123 Epoch 74 - Perplexity: 6.058368846351638
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6157 - loss: 1.8122
# Epoch 75/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6244 - loss: 1.7750 Epoch 75 - Perplexity: 5.924904404850551
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6244 - loss: 1.7751
# Epoch 76/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6336 - loss: 1.7173 Epoch 76 - Perplexity: 5.754374927816522
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6336 - loss: 1.7175
# Epoch 77/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6315 - loss: 1.7279 Epoch 77 - Perplexity: 5.683997020102774
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6314 - loss: 1.7279
# Epoch 78/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6287 - loss: 1.7163 Epoch 78 - Perplexity: 5.545747462968321
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6287 - loss: 1.7162
# Epoch 79/100
# 132/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6447 - loss: 1.6708  Epoch 79 - Perplexity: 5.401212438919498
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6446 - loss: 1.6710
# Epoch 80/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6485 - loss: 1.6393 Epoch 80 - Perplexity: 5.2960370205686935
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6484 - loss: 1.6395
# Epoch 81/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6510 - loss: 1.6309 Epoch 81 - Perplexity: 5.172224762268139
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6509 - loss: 1.6310
# Epoch 82/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6528 - loss: 1.5987 Epoch 82 - Perplexity: 5.060930307205221
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6528 - loss: 1.5988
# Epoch 83/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6537 - loss: 1.5995 Epoch 83 - Perplexity: 4.998655054441631
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6537 - loss: 1.5996
# Epoch 84/100
# 131/133 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6624 - loss: 1.5532 Epoch 84 - Perplexity: 4.863347120013819
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6622 - loss: 1.5539
# Epoch 85/100
# 128/133 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6613 - loss: 1.5655 Epoch 85 - Perplexity: 4.772227432105903
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6614 - loss: 1.5653
# Epoch 86/100
# 129/133 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6618 - loss: 1.5500 Epoch 86 - Perplexity: 4.692149570742356
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6618 - loss: 1.5499
# Epoch 87/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6679 - loss: 1.5258 Epoch 87 - Perplexity: 4.584210670454014
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6679 - loss: 1.5258
# Epoch 88/100
# 131/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6761 - loss: 1.4778 Epoch 88 - Perplexity: 4.497504798263716
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6760 - loss: 1.4784
# Epoch 89/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6816 - loss: 1.4488 Epoch 89 - Perplexity: 4.40690458964346
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6816 - loss: 1.4491
# Epoch 90/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6808 - loss: 1.4610 Epoch 90 - Perplexity: 4.345374902316854
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6808 - loss: 1.4611
# Epoch 91/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6835 - loss: 1.4356 Epoch 91 - Perplexity: 4.25945976642101
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6834 - loss: 1.4357
# Epoch 92/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6929 - loss: 1.3997 Epoch 92 - Perplexity: 4.162172578299255
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6929 - loss: 1.3998
# Epoch 93/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6900 - loss: 1.4102 Epoch 93 - Perplexity: 4.085969521876107
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6900 - loss: 1.4102
# Epoch 94/100
# 130/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6934 - loss: 1.3925 Epoch 94 - Perplexity: 4.029192615676287
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6933 - loss: 1.3926
# Epoch 95/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6991 - loss: 1.3717 Epoch 95 - Perplexity: 3.952772319563408
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6991 - loss: 1.3718
# Epoch 96/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7036 - loss: 1.3537 Epoch 96 - Perplexity: 3.8814102312859657
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7036 - loss: 1.3537
# Epoch 97/100
# 129/133 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6935 - loss: 1.3707 Epoch 97 - Perplexity: 3.8516722487724198
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6937 - loss: 1.3698
# Epoch 98/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7093 - loss: 1.3268 Epoch 98 - Perplexity: 3.7643074782863435
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7093 - loss: 1.3268
# Epoch 99/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7077 - loss: 1.3135 Epoch 99 - Perplexity: 3.7188778317500644
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7077 - loss: 1.3135
# Epoch 100/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7178 - loss: 1.2740 Epoch 100 - Perplexity: 3.6250087352801645
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7178 - loss: 1.2742
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3826 - loss: 6.1602
# Test Loss: 5.922313690185547
# Test Accuracy: 0.4067610204219818
# Test Perplexity: 373.2743567629284
#
# Sample Predictions using the test set:
# Input: blueberries as big as the end of your thumb,
# Actual Output: real sky blue, and heavy, and ready to drum
# Predicted Output: aged as the bloom like ended
#
# Input: got him by something he had on
# Actual Output: and blew him out on the icy crust
# Predicted Output: what me off the the dragon's his held
#
# Input: as if she had some sort of curvature,
# Actual Output: no matter if i have no errand there
# Predicted Output: sounds our he let had objection
#
# Input: but though repeatedly he strove
# Actual Output: and stamped and said things to himself,
# Predicted Output: if it again as that
#
# Input: those collars who shall i address them to,
# Actual Output: suppose you aren't awake when i come back
# Predicted Output: this would darkening of i am for

# %%
def generate_poetry(seed_text, model, tokenizer, max_len, num_lines=5):
    poetry = []
    input_seq = tokenizer.texts_to_sequences([seed_text])[0]
    input_seq = pad_sequences([input_seq], maxlen=max_len, padding='post')

    for _ in range(num_lines):
        decoder_input = np.zeros((1, max_len), dtype=int)
        generated_line = []
        for _ in range(max_len):
            output = model.predict([input_seq, decoder_input], verbose=0)
            next_word_prob = output[0, len(generated_line), :]
            next_word_idx = np.random.choice(len(next_word_prob), p=next_word_prob)
            if next_word_idx == 0:
                break
            generated_line.append(next_word_idx)
            decoder_input[0, len(generated_line) - 1] = next_word_idx
        generated_line_text = ' '.join([tokenizer.index_word.get(idx, '<UNK>') for idx in generated_line])
        poetry.append(generated_line_text)
        input_seq = pad_sequences([tokenizer.texts_to_sequences([generated_line_text])[0]], maxlen=max_len, padding='post')

    return '\n'.join(poetry)

seed = "The sun sets beyond the distant hill"
generated_poetry = generate_poetry(seed, model, tokenizer, max_input_len)
print("Generated Poetry:")
print(generated_poetry)
